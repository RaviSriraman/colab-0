# %% [markdown]
# <a href="https://colab.research.google.com/github/RaviSriraman/colab-0/blob/feature/sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: 10 random numbers using numpy

import numpy as np

random_numbers = np.random.rand(10)
random_numbers
# Out:
# array([0.72224035, 0.65259197, 0.4541353 , 0.96349387, 0.40076992,
#        0.98058493, 0.90428497, 0.51413009, 0.69160588, 0.77078828])
